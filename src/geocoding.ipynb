# %%
from geocoding import my_geocoding

mgeo = my_geocoding('../resource/train_geo.csv')

mgeo.table[(mgeo.table['score'] < 100) & (mgeo.table['precision'] != 'ROOFTOP')]
# Out:
# /Users/mashimashica/ichilab/DSS2020/DSS202002/src/geocoding.py:24: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   self.table = pd.read_csv(csvpath, encoding)
#           id      賃料                 所在地  \
# 103      104   95000     東京都台東区浅草５丁目64-8
# 163      164   82000     東京都北区赤羽３丁目28-26
# 206      207  107500     東京都練馬区豊玉中２丁目9-9
# 271      272  141000    東京都墨田区八広４丁目46-18
# 292      293  230000   東京都杉並区成田東２丁目22-14
# ...      ...     ...                 ...
# 31403  31404  113000  東京都港区海岸３丁目２１（以下未定）
# 31415  31416  104500     東京都江東区潮見１丁目２４－３
# 31428  31429  107000    東京都新宿区下落合１丁目10-9
# 31435  31436  243000   東京都杉並区上高井戸３丁目8-41
# 31439  31440   83000    東京都練馬区早宮１丁目35-18
#
#                                                     アクセス   間取り     築年数  方角  \
# 103    都営浅草線\t浅草駅\t徒歩17分\t\tつくばエクスプレス\t浅草(ＴＸ)駅\t徒歩10分...    1K   0年3ヶ月  北東
# ...

# %%
mgeo.geocode('../resource/train_geo.csv', address_list = ['住所'])
# Out:
#  ooooooooooooooooooo* 97.561 %

# %%
mgeo.table
# Out:
#                 施設名                  住所  score    precision           x  \
# 0          七宝保健センター      愛知県あま市七宝町桂弥勒28    100         FINE  136.796211
# 1          美和保健センター        愛知県あま市花正中之割2    100         FINE  136.784480
# 2         甚目寺総合福祉会館       愛知県あま市西今宿馬洗46    100         FINE  136.826811
# 3       七宝焼アートヴィレッジ  愛知県あま市七宝町遠島十三割2000    100         FINE  136.799559
# 4             七宝公民館  愛知県あま市七宝町安松小新田2337    100         FINE  136.796787
# 5           七宝総合体育館     愛知県あま市七宝町伊福宮東31     94  APPROXIMATE  136.797139
# 6        人権ふれあいセンター      愛知県あま市西今宿平割二32    100         FINE  136.833746
# 7      美和情報ふれあいセンター      愛知県あま市木田丁子ノ口61     94  APPROXIMATE  136.787913
# 8    篠田防災コミュニティセンター       愛知県あま市篠田三丁目51    100         FINE  136.777667
# 9   下萱津コミュニティ防災センター        愛知県あま市下萱津山伏8    100         FINE  136.839451
# 10  上萱津コミュニティ防災センター       愛知県あま市上萱津上野87    100         FINE  136.839308
# 11   坂牧コミュニティ防災センター        愛知県あま市坂牧阿原25    100         FINE  136.830267
# ...
