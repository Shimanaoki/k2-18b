# %%
from geocoding import my_geocoding

mgeo = my_geocoding('../resource/test_geo.csv')

mgeo.table.loc[(mgeo.table['score'] < 100) & (mgeo.table['precision'] != 'ROOFTOP'), 'score'] = 0
# Out:
# /Users/mashimashica/ichilab/DSS2020/k2-18b/src/geocoding.py:24: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   self.table = pd.read_csv(csvpath, encoding)

# %%
mgeo.geocode('../resource/test_geo.csv', address_list = ['所在地'], use_googlemaps = False)
# Out:
#  ooooooooooooooooooo* 99.917 %

# %%
mgeo.table[(mgeo.table['score'] < 100) & (mgeo.table['precision'] != 'ROOFTOP')]
# Out:
#           id                所在地  \
# 46     31517    東京都足立区新田１丁目2-23
# 109    31580  東京都杉並区成田東２丁目22-16
# 227    31698       東京都港区麻布十番２丁目
# 350    31821   東京都葛飾区西水元２丁目１０－９
# 364    31835  東京都大田区大森西３丁目189-1
# ...      ...                ...
# 30503  61974    東京都足立区新田１丁目2-23
# 30882  62353   東京都荒川区南千住１丁目１－１９
# 31079  62550  東京都大田区下丸子２丁目31－16
# 31192  62663   東京都豊島区池袋２丁目54-16
# 31236  62707  東京都足立区谷在家１丁目14-11
#
#                                                     アクセス         間取り     築年数  \
# 46     南北線\t王子神谷駅\t徒歩13分\t\t南北線\t志茂駅\t徒歩19分\t\t京浜東北線\...        1LDK   0年4ヶ月
# 109    京王井の頭線\t浜田山駅\t徒歩17分\t\t京王井の頭線\t西永福駅\t徒歩16分\t\t...        3LDK   5年5ヶ月
# 227    南北線\t麻布十番駅\t徒歩1分\t\t都営大江戸線\t赤羽橋駅\t徒歩11分\t\t日比谷...         2DK  38年5ヶ月
# 350    常磐線\t亀有駅\t徒歩40分\t\t常磐線\t金町(東京都)駅\t/バス(14分)西水元２...        4LDK  5年10ヶ月
# 364    京急本線\t大森町駅\t徒歩2分\t\t京急本線\t梅屋敷(東京都)駅\t徒歩9分\t\t京...        1LDK   0年0ヶ月
# ...                                                  ...         ...     ...
# ...
