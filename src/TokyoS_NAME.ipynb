# %%
import geopandas as gpd

# %%
path = '../resource/h27ka13.shp'

gdf = gpd.read_file(path, encoding = 'shift-jis')

gdf
# Out:
#          KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME  S_NAME KIGO_E  HCODE  \
# 0     13101001001   13  101  001001       東京都      千代田区  丸の内１丁目   None   8101
# 1     13101001002   13  101  001002       東京都      千代田区  丸の内２丁目   None   8101
# 2     13101001003   13  101  001003       東京都      千代田区  丸の内３丁目   None   8101
# 3     13101002001   13  101  002001       東京都      千代田区  大手町１丁目   None   8101
# 4     13101002002   13  101  002002       東京都      千代田区  大手町２丁目   None   8101
# ...           ...  ...  ...     ...       ...       ...     ...    ...    ...
# 3146  13123051002   13  123  051002       東京都      江戸川区  谷河内２丁目   None   8101
# 3147  13123052001   13  123  052001       東京都      江戸川区  東松本１丁目   None   8101
# 3148  13123052002   13  123  052002       東京都      江戸川区  東松本２丁目   None   8101
# 3149  13123053001   13  123  053001       東京都      江戸川区  西篠崎１丁目   None   8101
# 3150  13123053002   13  123  053002       東京都      江戸川区  西篠崎２丁目   None   8101
#
# ...

# %%
gdf[['S_NAME', 'CITY_NAME']].to_csv('Tokyo_Slist.csv', index=False)
# Out:
#       S_NAME CITY_NAME
# 0     丸の内１丁目      千代田区
# 1     丸の内２丁目      千代田区
# 2     丸の内３丁目      千代田区
# 3     大手町１丁目      千代田区
# 4     大手町２丁目      千代田区
# ...      ...       ...
# 3146  谷河内２丁目      江戸川区
# 3147  東松本１丁目      江戸川区
# 3148  東松本２丁目      江戸川区
# 3149  西篠崎１丁目      江戸川区
# 3150  西篠崎２丁目      江戸川区
#
# [3151 rows x 2 columns]

# %%
gdf['AREA_NAME'].to_csv('Tokyo_Slist.csv', index=False)
# Out:
# C:\Users\mashi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
